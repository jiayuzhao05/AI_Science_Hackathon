# %% [markdown]
# This jupyter gives you a simple example of how you should use the Simulated Network (asynchronous) environment. This environment is not meant as a training ground of your algorithms, but only to check whether or not your algorithm can be executed and if it is fast enough to create a response in time. (Set stim_period = 100 to be sure).

# %%
import gymnasium as gym
import numpy as np

# Add parent directory to path
import sys
from pathlib import Path
current_dir = Path().resolve()
root_dir = current_dir.parent
if str(root_dir) not in sys.path:
    sys.path.insert(0,str(root_dir))

from Gyms.SimulatedNetworkSync import SimulatedNetworkSync

# %%
# Define size of state and action spaces, as well as stimulation period
state_dim   = 4   # Dimension of reduced state space
action_dim  = 5   # Number of stimuli in action space. Must be less or equal to 5 (each stimulus needs a value of {0,1,2,3,4}
stim_period = 250 # stimulation period, meaning that an action is applied every {stim_period} ms

# %%
# Create environment and initialize it
env      = SimulatedNetworkSync(action_dim=action_dim,state_dim=state_dim,stim_period=stim_period)
state, _ = env.reset()
env.render() # This function gives you the current state + reward, which both is 0 after initialization
# Out:
# Current state: [0. 0. 0. 0.], Reward: 0

# %%
# Example code, that stimulates the network 100 times with a randomly sampled action, while calculating also the average reward received

total_reward = 0
action_count = 0

for _ in range(100):
    # For simplicity, choose a random action
    action = env.action_space.sample()
    print(f"Stimulate with action: {action}")
    
    state, reward, terminated, truncated, info = env.step(action)
    total_reward += reward
    action_count += 1

    # Plot information
    print(f"Info: {info}")

    print("-----------------------------")
# Out:
# Stimulate with action: [1 0 0 4 0]
# Info: {'spikes': array([ 3.66274782,  6.52064539, 18.28757563, 19.9999    ]), 'elecs': array([0, 1, 3, 0]), 'action': array([1, 0, 0, 4, 0]), 'missed_cyc': 35, 'stim_id': 36, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 4 4 2 0]
# Info: {'spikes': array([ 4.16919465,  7.3772226 ,  8.23823398,  9.06134414, 11.97937499,
#        13.31956974, 13.61947624, 14.80163763, 15.63916044, 19.1321302 ]), 'elecs': array([1, 3, 2, 2, 0, 3, 0, 1, 0, 2]), 'action': array([2, 4, 4, 2, 0]), 'missed_cyc': 0, 'stim_id': 37, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 1 4 1 1]
# Info: {'spikes': array([ 7.51955866, 12.64033439, 12.76107604, 14.28467792, 15.89464795,
#        18.59747563, 18.84390609, 19.9999    ]), 'elecs': array([0, 3, 1, 0, 0, 1, 0, 1]), 'action': array([0, 1, 4, 1, 1]), 'missed_cyc': 0, 'stim_id': 38, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 3 0 1 2]
# Info: {'spikes': array([ 4.26627661,  7.73004548,  8.51623   , 11.23000637, 15.45815769,
#        18.57957059, 19.08288336, 19.9999    ]), 'elecs': array([1, 2, 2, 3, 0, 1, 1, 2]), 'action': array([2, 3, 0, 1, 2]), 'missed_cyc': 0, 'stim_id': 39, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 4 1 0 1]
# Info: {'spikes': array([ 2.26876438,  8.3471193 ,  8.84657274, 13.2114645 , 13.67036942,
#        16.27949134, 19.9999    , 19.9999    ]), 'elecs': array([1, 3, 2, 0, 0, 1, 0, 1]), 'action': array([2, 4, 1, 0, 1]), 'missed_cyc': 0, 'stim_id': 40, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 3 0 4 2]
# Info: {'spikes': array([ 3.84688979,  8.12381093, 10.18887886, 11.07959632, 16.00009595,
#        19.38308223, 19.49901348, 19.9999    ]), 'elecs': array([1, 2, 2, 3, 3, 0, 1, 2]), 'action': array([2, 3, 0, 4, 2]), 'missed_cyc': 0, 'stim_id': 41, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 1 2 1 1]
# Info: {'spikes': array([ 5.98858423,  9.75824264, 12.22315079, 15.4722402 , 16.82009575,
#        18.77270061, 19.41773996, 19.9999    ]), 'elecs': array([0, 1, 1, 0, 2, 0, 1, 1]), 'action': array([0, 1, 2, 1, 1]), 'missed_cyc': 0, 'stim_id': 42, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 0 3 3 2]
# Info: {'spikes': array([11.4342869 , 17.17819886, 17.4601048 , 18.93633999, 19.9999    ,
#        19.9999    ]), 'elecs': array([2, 2, 3, 3, 1, 2]), 'action': array([0, 0, 3, 3, 2]), 'missed_cyc': 0, 'stim_id': 43, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 4 4 4 0]
# Info: {'spikes': array([ 3.69404648,  6.71647727,  9.30451669, 11.53878312, 12.82834276,
#        15.58243484, 15.90593752, 19.9999    ]), 'elecs': array([1, 3, 2, 0, 3, 0, 3, 0]), 'action': array([2, 4, 4, 4, 0]), 'missed_cyc': 0, 'stim_id': 44, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3 3 2 1]
# Info: {'spikes': array([ 3.46437796,  8.19833269,  8.61708043, 10.66187964, 13.56741011,
#        15.04038863, 15.53428076, 18.01465367, 18.75607858, 19.9999    ,
#        19.9999    ]), 'elecs': array([0, 1, 2, 2, 3, 1, 3, 2, 3, 0, 1]), 'action': array([1, 3, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 45, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 0 0 0 3]
# Info: {'spikes': array([ 4.56481591,  7.10884397, 12.09225813, 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 3, 2, 3]), 'action': array([4, 0, 0, 0, 3]), 'missed_cyc': 0, 'stim_id': 46, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 1 0 2 1]
# Info: {'spikes': array([ 2.06147036,  8.27131229,  8.38981614,  8.9499708 , 13.33428923,
#        15.85881108, 19.2826304 , 19.9999    , 19.9999    ]), 'elecs': array([2, 1, 0, 3, 1, 1, 2, 0, 1]), 'action': array([3, 1, 0, 2, 1]), 'missed_cyc': 0, 'stim_id': 47, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 4 2 1 4]
# Info: {'spikes': array([ 3.09787537,  7.11148075,  8.33965666,  9.22800207, 12.36687979,
#        17.1060659 , 18.18331202, 18.85205238, 19.26498274, 19.9999    ]), 'elecs': array([2, 3, 3, 1, 0, 2, 0, 1, 3, 0]), 'action': array([3, 4, 2, 1, 4]), 'missed_cyc': 0, 'stim_id': 48, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 1 0 3 1]
# Info: {'spikes': array([ 4.01669663,  8.11879395,  8.53213575, 11.19570719, 16.21060208,
#        19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 0, 1, 2, 3, 0, 1]), 'action': array([4, 1, 0, 3, 1]), 'missed_cyc': 0, 'stim_id': 49, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3 3 0 1]
# Info: {'spikes': array([ 2.9862102 ,  6.36944957,  8.46579901, 12.38982171, 12.55941727,
#        16.58863057, 19.74696038, 19.9999    ]), 'elecs': array([0, 2, 1, 2, 3, 3, 0, 1]), 'action': array([1, 3, 3, 0, 1]), 'missed_cyc': 0, 'stim_id': 50, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 4 0 2 3]
# Info: {'spikes': array([ 5.59340455,  7.76363932,  7.77118086, 12.29321298, 16.81320792,
#        19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([2, 3, 3, 0, 1, 2, 2, 3]), 'action': array([3, 4, 0, 2, 3]), 'missed_cyc': 0, 'stim_id': 51, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 0 1 0 4]
# Info: {'spikes': array([ 4.44845803,  7.9486676 , 11.927156  , 15.00205241, 18.10070117,
#        19.9999    ]), 'elecs': array([3, 0, 0, 1, 3, 0]), 'action': array([4, 0, 1, 0, 4]), 'missed_cyc': 0, 'stim_id': 52, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 3 1 4 0]
# Info: {'spikes': array([ 9.16038705, 13.39783361, 13.48839345, 14.47968587, 15.74858388,
#        19.9999    ]), 'elecs': array([2, 3, 0, 3, 1, 0]), 'action': array([0, 3, 1, 4, 0]), 'missed_cyc': 0, 'stim_id': 53, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 4 1 3 0]
# Info: {'spikes': array([ 2.82381662,  5.75202316,  9.52329412, 11.41452539, 11.54121929,
#        15.9290621 , 16.58055288, 18.93916739]), 'elecs': array([0, 3, 1, 0, 0, 2, 1, 3]), 'action': array([1, 4, 1, 3, 0]), 'missed_cyc': 0, 'stim_id': 54, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 4 2 4 4]
# Info: {'spikes': array([ 7.80967029, 11.59145856, 12.79733581, 16.77010661, 16.90159555,
#        19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 1, 3, 2, 0, 3, 0]), 'action': array([0, 4, 2, 4, 4]), 'missed_cyc': 0, 'stim_id': 55, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2 1 3 0]
# Info: {'spikes': array([ 5.24994117,  7.46311119,  7.8278464 , 11.23752572, 12.3957905 ,
#        15.08826901, 15.62726765, 15.66319194, 17.0042219 , 19.9999    ]), 'elecs': array([0, 1, 1, 0, 2, 2, 3, 1, 2, 3]), 'action': array([1, 2, 1, 3, 0]), 'missed_cyc': 0, 'stim_id': 56, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2 3 2 2]
# Info: {'spikes': array([ 2.51213585,  4.08188408,  7.51772734,  7.88367557, 11.78600496,
#        12.72634014, 14.9982983 , 15.26733091, 16.43865361, 19.97300963,
#        19.9999    , 19.9999    ]), 'elecs': array([0, 2, 1, 1, 2, 2, 3, 3, 1, 1, 2, 2]), 'action': array([1, 2, 3, 2, 2]), 'missed_cyc': 0, 'stim_id': 57, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 1 4 3 1]
# Info: {'spikes': array([ 4.48712139,  6.30983142,  7.84495386, 11.40081582, 11.97927304,
#        13.34867247, 15.4995286 , 16.68438578, 19.51881481, 19.77023682,
#        19.9999    ]), 'elecs': array([3, 0, 0, 3, 1, 3, 0, 2, 3, 0, 1]), 'action': array([4, 1, 4, 3, 1]), 'missed_cyc': 0, 'stim_id': 58, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 3 4 2 3]
# Info: {'spikes': array([ 3.26840641,  6.40148524,  8.09257339, 11.14563822, 13.49041793,
#        14.66244124, 14.94637313, 19.4874224 , 19.80716968, 19.9999    ]), 'elecs': array([2, 2, 3, 3, 3, 1, 0, 2, 2, 3]), 'action': array([3, 3, 4, 2, 3]), 'missed_cyc': 0, 'stim_id': 59, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 3 0 1 3]
# Info: {'spikes': array([ 3.51084414,  5.54682741,  7.96346997,  9.74238867, 11.3101906 ,
#        17.43589474, 18.08271474, 19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([1, 3, 0, 2, 3, 0, 3, 1, 2, 3]), 'action': array([4, 3, 0, 1, 3]), 'missed_cyc': 0, 'stim_id': 60, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 2 0 1 4]
# Info: {'spikes': array([ 4.17274643,  7.32674023,  8.1721828 , 12.70451784, 15.05373639,
#        17.59788302, 19.12933493, 19.9999    ]), 'elecs': array([3, 1, 0, 2, 0, 1, 3, 0]), 'action': array([4, 2, 0, 1, 4]), 'missed_cyc': 0, 'stim_id': 61, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 3 1 2 4]
# Info: {'spikes': array([ 4.36495271,  8.17454463,  8.76724816, 11.26777175, 14.19912087,
#        16.88516695, 17.25080013, 19.06246927, 19.47999664, 19.9999    ]), 'elecs': array([2, 3, 2, 3, 0, 1, 1, 3, 2, 0]), 'action': array([3, 3, 1, 2, 4]), 'missed_cyc': 0, 'stim_id': 62, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0 2 4 1]
# Info: {'spikes': array([ 5.04458093,  8.31412544, 12.46653646, 14.03891847, 16.71455172,
#        18.25877214, 18.72632579, 19.61033141, 19.9999    ]), 'elecs': array([1, 2, 1, 2, 1, 3, 0, 0, 1]), 'action': array([2, 0, 2, 4, 1]), 'missed_cyc': 0, 'stim_id': 63, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 4 1 4 2]
# Info: {'spikes': array([ 4.58786687,  7.08448389,  7.13554597, 11.02907839, 11.57278159,
#        12.5522882 , 14.58527051, 14.72326886, 19.70998119, 19.9999    ,
#        19.9999    ]), 'elecs': array([0, 3, 1, 0, 0, 2, 1, 3, 0, 1, 2]), 'action': array([1, 4, 1, 4, 2]), 'missed_cyc': 0, 'stim_id': 64, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 1 1 4 2]
# Info: {'spikes': array([ 1.08789902,  6.99337984, 12.31140245, 12.74786069, 15.18997876,
#        15.96696149, 18.7777212 , 19.96522077, 19.9999    ]), 'elecs': array([1, 0, 1, 0, 1, 3, 0, 1, 2]), 'action': array([0, 1, 1, 4, 2]), 'missed_cyc': 0, 'stim_id': 65, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1 3 2 1]
# Info: {'spikes': array([ 4.1511749 ,  7.15951089,  7.32944767, 10.73209098, 11.05896259,
#        13.31334073, 15.83339096, 16.5701315 , 19.15773791, 19.89935585,
#        19.9999    ]), 'elecs': array([0, 0, 1, 2, 2, 1, 3, 1, 2, 0, 1]), 'action': array([1, 1, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 66, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 1 0 1 3]
# Info: {'spikes': array([ 4.04002484,  6.72789882,  7.6703413 , 11.6316328 , 11.76029384,
#        16.73812221, 19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 0, 1, 1, 0, 1, 2, 3]), 'action': array([4, 1, 0, 1, 3]), 'missed_cyc': 0, 'stim_id': 67, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 2 1 1 4]
# Info: {'spikes': array([ 1.37136832,  6.62511691,  9.58042719, 11.17801021, 11.65636593,
#        15.42431001, 16.29618323, 17.86808825, 19.78690328, 19.9999    ]), 'elecs': array([2, 3, 1, 0, 2, 0, 1, 3, 1, 0]), 'action': array([3, 2, 1, 1, 4]), 'missed_cyc': 0, 'stim_id': 68, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 0 0 2 3]
# Info: {'spikes': array([ 5.83216097,  7.47117477, 14.90998691, 18.65547888, 19.9999    ,
#        19.9999    ]), 'elecs': array([2, 3, 1, 2, 2, 3]), 'action': array([3, 0, 0, 2, 3]), 'missed_cyc': 0, 'stim_id': 69, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1 4 2 1]
# Info: {'spikes': array([ 3.52304609,  7.32062895,  7.38390434, 10.12474275, 10.59528003,
#        15.71564849, 16.32915674, 19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([0, 1, 0, 1, 3, 1, 0, 2, 0, 1]), 'action': array([1, 1, 4, 2, 1]), 'missed_cyc': 0, 'stim_id': 70, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 2 0 0 4]
# Info: {'spikes': array([ 2.25376048,  7.61700758,  9.45810457, 10.86327564, 18.70186215,
#        19.59055485, 19.9999    ]), 'elecs': array([1, 2, 1, 2, 3, 3, 0]), 'action': array([2, 2, 0, 0, 4]), 'missed_cyc': 0, 'stim_id': 71, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 4 1 1 2]
# Info: {'spikes': array([ 4.6028113 ,  4.72102572,  7.7845085 ,  9.00988907, 10.53852246,
#        11.95794997, 16.08825612, 16.4909116 , 19.9999    , 19.9999    ,
#        19.9999    ]), 'elecs': array([3, 1, 2, 3, 0, 0, 1, 0, 1, 1, 2]), 'action': array([2, 4, 1, 1, 2]), 'missed_cyc': 0, 'stim_id': 72, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 1 4 2 2]
# Info: {'spikes': array([ 2.59272278,  7.56205324,  8.93955324, 10.99661554, 11.35625161,
#        15.28440961, 16.33161898, 18.69070006, 19.18598306, 19.9999    ]), 'elecs': array([2, 3, 0, 1, 3, 0, 1, 2, 1, 2]), 'action': array([3, 1, 4, 2, 2]), 'missed_cyc': 0, 'stim_id': 73, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 2 3 1 2]
# Info: {'spikes': array([ 3.55810784,  8.73870784,  8.88566064, 11.08372355, 12.80155139,
#        15.26557967, 15.69692431, 19.66433692, 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 1, 2, 2, 0, 3, 1, 1, 2]), 'action': array([4, 2, 3, 1, 2]), 'missed_cyc': 0, 'stim_id': 74, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 3 2 0 2]
# Info: {'spikes': array([ 3.39743573,  7.99680173, 11.79364276, 12.2990209 , 16.5276212 ,
#        17.37315479, 19.94017966, 19.9999    ]), 'elecs': array([3, 2, 3, 1, 2, 2, 1, 2]), 'action': array([0, 3, 2, 0, 2]), 'missed_cyc': 0, 'stim_id': 75, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 1 2 1 4]
# Info: {'spikes': array([ 3.8718663 ,  7.60387498,  7.97815557, 12.4266379 , 14.10300045,
#        14.50686975, 15.72688604, 17.70689518, 18.62966123, 19.9999    ,
#        19.9999    ]), 'elecs': array([2, 3, 0, 1, 1, 0, 2, 3, 3, 1, 0]), 'action': array([3, 1, 2, 1, 4]), 'missed_cyc': 0, 'stim_id': 76, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 0 4 1 1]
# Info: {'spikes': array([ 3.87281874,  4.6763677 ,  7.82418299, 11.55279563, 14.90628166,
#        16.37930139, 16.64927922, 19.08365508, 19.60419681, 19.9999    ]), 'elecs': array([2, 3, 3, 3, 0, 0, 0, 1, 0, 1]), 'action': array([3, 0, 4, 1, 1]), 'missed_cyc': 0, 'stim_id': 77, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3 4 0 0]
# Info: {'spikes': array([ 1.2497687 ,  4.03638904,  8.23716584,  8.41989114, 12.30326466,
#        12.42523576, 17.21865098]), 'elecs': array([0, 0, 2, 1, 3, 3, 0]), 'action': array([1, 3, 4, 0, 0]), 'missed_cyc': 0, 'stim_id': 78, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 1 4 4 1]
# Info: {'spikes': array([ 3.54910618,  6.09936871,  8.17772531,  9.54801439, 10.22761445,
#        13.09758767, 15.68485862, 16.69678239, 19.67162584, 19.9999    ,
#        19.9999    , 19.9999    ]), 'elecs': array([3, 2, 0, 0, 3, 1, 3, 0, 0, 0, 0, 1]), 'action': array([4, 1, 4, 4, 1]), 'missed_cyc': 0, 'stim_id': 79, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0 3 2 0]
# Info: {'spikes': array([ 4.75530526,  6.19371994, 11.70641774, 14.08192511, 16.21545777,
#        19.56677206]), 'elecs': array([1, 2, 2, 3, 1, 2]), 'action': array([2, 0, 3, 2, 0]), 'missed_cyc': 0, 'stim_id': 80, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 2 0 1 0]
# Info: {'spikes': array([ 3.74392695,  7.1773301 ,  8.63375765, 13.97614864, 16.55281264,
#        19.9999    ]), 'elecs': array([3, 0, 1, 2, 0, 1]), 'action': array([4, 2, 0, 1, 0]), 'missed_cyc': 0, 'stim_id': 81, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 1 1 0 4]
# Info: {'spikes': array([ 4.5199553 ,  6.339256  ,  8.34795981,  8.45738016,  9.36995614,
#        10.13955342, 12.23343602, 16.32038027, 19.9999    , 19.9999    ]), 'elecs': array([2, 0, 0, 2, 3, 0, 1, 1, 3, 0]), 'action': array([3, 1, 1, 0, 4]), 'missed_cyc': 0, 'stim_id': 82, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 2 3 3 0]
# Info: {'spikes': array([ 7.28545174,  9.04045982, 12.2248087 , 12.30722764, 15.47750511,
#        16.2327976 , 19.55118424]), 'elecs': array([3, 1, 2, 2, 2, 3, 3]), 'action': array([0, 2, 3, 3, 0]), 'missed_cyc': 0, 'stim_id': 83, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 0 1 0 1]
# Info: {'spikes': array([ 3.85494323,  9.42070695, 11.99408184, 13.65350354, 16.13373173,
#        18.79954359, 19.9999    ]), 'elecs': array([3, 0, 0, 3, 1, 0, 1]), 'action': array([4, 0, 1, 0, 1]), 'missed_cyc': 0, 'stim_id': 84, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 0 4 2 3]
# Info: {'spikes': array([ 3.4831312 ,  9.84176941, 12.40219126, 15.68068993, 17.35887014,
#        19.28575012, 19.68030994, 19.9999    ]), 'elecs': array([2, 3, 3, 0, 1, 2, 2, 3]), 'action': array([3, 0, 4, 2, 3]), 'missed_cyc': 0, 'stim_id': 85, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 0 0 0 2]
# Info: {'spikes': array([ 1.88353012,  7.50885572, 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 1, 2]), 'action': array([4, 0, 0, 0, 2]), 'missed_cyc': 0, 'stim_id': 86, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 4 4 1 1]
# Info: {'spikes': array([ 8.64256554, 11.90560102, 12.28675044, 16.7876457 , 17.15574048,
#        19.53127035, 19.9999    , 19.9999    ]), 'elecs': array([3, 3, 0, 0, 0, 0, 1, 1]), 'action': array([0, 4, 4, 1, 1]), 'missed_cyc': 0, 'stim_id': 87, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 0 1 4 0]
# Info: {'spikes': array([ 3.13897784,  5.80583466,  6.3441581 , 11.05483312, 16.42955263,
#        16.86123311, 18.02927091, 19.01037825]), 'elecs': array([0, 3, 1, 0, 3, 1, 0, 0]), 'action': array([1, 0, 1, 4, 0]), 'missed_cyc': 0, 'stim_id': 88, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1 2 2 4]
# Info: {'spikes': array([ 3.39330855,  6.62341565,  7.63913106,  8.79414891, 10.81638473,
#        13.07090011, 15.4833599 , 16.89141183, 19.9999    , 19.9999    ,
#        19.9999    ]), 'elecs': array([0, 0, 1, 1, 1, 1, 2, 1, 2, 3, 0]), 'action': array([1, 1, 2, 2, 4]), 'missed_cyc': 0, 'stim_id': 89, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 2 0 4 2]
# Info: {'spikes': array([ 4.51058466,  6.62986428,  7.95898528, 12.81282445, 16.27296781,
#        16.75278093, 19.65823428, 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 1, 2, 3, 2, 1, 0, 2]), 'action': array([4, 2, 0, 4, 2]), 'missed_cyc': 0, 'stim_id': 90, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 2 3 0 2]
# Info: {'spikes': array([ 4.39538741,  9.95483461,  9.97627772, 11.71366545, 12.75153038,
#        14.73326843, 19.9999    , 19.9999    ]), 'elecs': array([3, 1, 0, 2, 2, 3, 1, 2]), 'action': array([4, 2, 3, 0, 2]), 'missed_cyc': 0, 'stim_id': 91, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 0 2 0 3]
# Info: {'spikes': array([ 4.78500838,  8.30509934, 10.00998737, 12.47370619, 17.11446507,
#        18.4679719 , 19.9999    ]), 'elecs': array([3, 0, 3, 1, 2, 2, 3]), 'action': array([4, 0, 2, 0, 3]), 'missed_cyc': 0, 'stim_id': 92, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 3 4 4 1]
# Info: {'spikes': array([ 3.89355815,  8.36560277,  9.06164781, 12.01446931, 13.18830156,
#        15.00774406, 16.64495692, 19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([3, 2, 0, 3, 3, 0, 3, 0, 0, 1]), 'action': array([4, 3, 4, 4, 1]), 'missed_cyc': 0, 'stim_id': 93, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 2 3 0 1]
# Info: {'spikes': array([ 5.17058754,  7.60852448,  8.53421774, 11.39901052, 11.72214543,
#        15.99783516, 19.30651578, 19.9999    ]), 'elecs': array([2, 1, 3, 2, 2, 3, 0, 1]), 'action': array([3, 2, 3, 0, 1]), 'missed_cyc': 0, 'stim_id': 94, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 2 4 1 4]
# Info: {'spikes': array([ 2.48013545,  7.83027465,  8.00004009, 12.38453444, 12.56260186,
#        15.32351655, 15.84598875, 18.61393169, 19.9999    , 19.9999    ]), 'elecs': array([2, 3, 1, 3, 2, 0, 0, 1, 3, 0]), 'action': array([3, 2, 4, 1, 4]), 'missed_cyc': 0, 'stim_id': 95, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 1 3 4 2]
# Info: {'spikes': array([ 5.21568321,  7.57680979,  7.62753117, 11.47139565, 12.30972908,
#        15.91182409, 16.04119318, 19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([2, 0, 3, 2, 1, 3, 3, 0, 1, 2]), 'action': array([3, 1, 3, 4, 2]), 'missed_cyc': 0, 'stim_id': 96, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 4 1 1 0]
# Info: {'spikes': array([ 5.98154095,  7.30845454,  8.58108693, 10.26326234, 12.09254286,
#        14.51075565, 15.75099852, 19.59793543]), 'elecs': array([3, 3, 0, 0, 0, 1, 0, 1]), 'action': array([4, 4, 1, 1, 0]), 'missed_cyc': 0, 'stim_id': 97, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 4 3 2 0]
# Info: {'spikes': array([ 4.20982399,  6.639221  ,  8.85313641, 11.54738374, 13.25074028,
#        16.04155548, 17.47067468, 19.9999    ]), 'elecs': array([1, 3, 2, 2, 0, 1, 3, 2]), 'action': array([2, 4, 3, 2, 0]), 'missed_cyc': 0, 'stim_id': 98, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0 1 0 3]
# Info: {'spikes': array([ 0.64948847,  2.4076194 ,  9.79609668, 10.59111418, 15.93033308,
#        19.9999    , 19.9999    ]), 'elecs': array([1, 1, 2, 0, 1, 2, 3]), 'action': array([2, 0, 1, 0, 3]), 'missed_cyc': 0, 'stim_id': 99, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 0 3 1 1]
# Info: {'spikes': array([ 4.94140073,  7.01753188, 11.32720717, 15.08681986, 15.76625887,
#        19.63850277, 19.9999    , 19.9999    ]), 'elecs': array([2, 3, 2, 0, 3, 0, 1, 1]), 'action': array([3, 0, 3, 1, 1]), 'missed_cyc': 0, 'stim_id': 100, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0 3 3 1]
# Info: {'spikes': array([ 5.49986325,  6.6670419 , 11.93482107, 14.55144807, 15.9751252 ,
#        19.8337938 , 19.9999    , 19.9999    ]), 'elecs': array([1, 2, 2, 2, 3, 3, 0, 1]), 'action': array([2, 0, 3, 3, 1]), 'missed_cyc': 0, 'stim_id': 101, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 4 3 2 1]
# Info: {'spikes': array([ 4.29559999,  7.20721325,  8.42987339, 12.96892795, 13.17608357,
#        14.23754253, 15.62932394, 16.5244447 , 18.82607379, 19.76399848,
#        19.9999    ]), 'elecs': array([1, 3, 2, 2, 0, 3, 3, 1, 0, 2, 1]), 'action': array([2, 4, 3, 2, 1]), 'missed_cyc': 0, 'stim_id': 102, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 0 0 1 3]
# Info: {'spikes': array([10.3688312 , 15.53195692, 19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([3, 0, 1, 2, 3]), 'action': array([0, 0, 0, 1, 3]), 'missed_cyc': 0, 'stim_id': 103, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 1 3 1 2]
# Info: {'spikes': array([ 0.11917359,  5.28237398,  7.39504776,  7.4574001 ,  8.71059653,
#         9.96683136, 12.07411465, 12.30395711, 16.47285791, 17.2477876 ,
#        19.43104714, 19.9999    , 19.9999    ]), 'elecs': array([3, 2, 0, 3, 1, 0, 1, 2, 3, 0, 1, 1, 2]), 'action': array([3, 1, 3, 1, 2]), 'missed_cyc': 0, 'stim_id': 104, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1 2 4 0]
# Info: {'spikes': array([ 4.87117772,  6.66736553,  6.6793783 ,  7.87088232, 11.79739656,
#        12.40159119, 16.07885887, 18.07490686, 19.56745505]), 'elecs': array([0, 1, 0, 0, 1, 1, 2, 3, 0]), 'action': array([1, 1, 2, 4, 0]), 'missed_cyc': 0, 'stim_id': 105, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 4 0 0 1]
# Info: {'spikes': array([ 2.85412603,  4.96960881,  6.69157687,  7.37168885, 11.78201978,
#        17.68119023, 19.9999    ]), 'elecs': array([0, 3, 1, 3, 0, 0, 1]), 'action': array([1, 4, 0, 0, 1]), 'missed_cyc': 0, 'stim_id': 106, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 0 1 2 2]
# Info: {'spikes': array([ 2.27390872,  8.08374577, 11.93978632, 15.83617142, 17.08806971,
#        18.79050127, 19.67488477, 19.9999    ]), 'elecs': array([0, 1, 0, 1, 1, 1, 2, 2]), 'action': array([1, 0, 1, 2, 2]), 'missed_cyc': 0, 'stim_id': 107, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 4 4 0 2]
# Info: {'spikes': array([ 5.17361988,  8.98780571,  9.27206547, 12.01060421, 12.40191414,
#        16.26687208, 19.84280669, 19.9999    ]), 'elecs': array([3, 0, 3, 3, 0, 0, 1, 2]), 'action': array([4, 4, 4, 0, 2]), 'missed_cyc': 0, 'stim_id': 108, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 3 1 3 2]
# Info: {'spikes': array([ 2.74637538,  6.93210538,  7.74724038, 11.44781888, 12.32015474,
#        16.56960321, 17.36048339, 18.36892318, 19.18252888, 19.9999    ]), 'elecs': array([1, 2, 2, 0, 3, 2, 1, 1, 3, 2]), 'action': array([2, 3, 1, 3, 2]), 'missed_cyc': 0, 'stim_id': 109, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 1 2 1 1]
# Info: {'spikes': array([ 7.26773908,  9.1212762 , 12.50409749, 14.4099943 , 14.96306022,
#        19.9462768 , 19.9999    , 19.9999    ]), 'elecs': array([0, 1, 1, 0, 2, 0, 1, 1]), 'action': array([0, 1, 2, 1, 1]), 'missed_cyc': 0, 'stim_id': 110, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 1 1 1 1]
# Info: {'spikes': array([ 4.0809532 ,  7.52214904,  8.20290339,  9.96100839, 12.52565303,
#        13.55482234, 15.63804521, 15.66430723, 18.06207124, 18.84432193,
#        19.9999    ]), 'elecs': array([1, 3, 0, 2, 0, 1, 0, 1, 0, 1, 1]), 'action': array([2, 1, 1, 1, 1]), 'missed_cyc': 0, 'stim_id': 111, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 4 4 0 0]
# Info: {'spikes': array([ 4.14785686,  4.95295292,  5.44310668,  6.25689498,  7.70051158,
#        10.41690602, 12.75786228, 13.80313043, 16.56868001]), 'elecs': array([3, 0, 2, 3, 0, 0, 3, 1, 0]), 'action': array([4, 4, 4, 0, 0]), 'missed_cyc': 0, 'stim_id': 112, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1 3 3 0]
# Info: {'spikes': array([ 2.26427641,  3.74084027,  6.69106373,  7.89313707, 12.02814252,
#        12.0845889 , 15.28490911, 16.24127356, 19.9999    ]), 'elecs': array([0, 3, 1, 0, 1, 2, 2, 3, 3]), 'action': array([1, 1, 3, 3, 0]), 'missed_cyc': 0, 'stim_id': 113, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3 0 1 2]
# Info: {'spikes': array([ 2.17351377,  4.33256881,  7.70042001,  8.11496028,  9.94590401,
#        10.68717745, 16.26575685, 19.33907215, 19.9999    , 19.9999    ]), 'elecs': array([0, 0, 1, 2, 3, 3, 0, 1, 1, 2]), 'action': array([1, 3, 0, 1, 2]), 'missed_cyc': 0, 'stim_id': 114, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 4 0 4 0]
# Info: {'spikes': array([ 7.48692157, 13.5112098 , 17.79016681, 19.9999    ]), 'elecs': array([3, 0, 3, 0]), 'action': array([0, 4, 0, 4, 0]), 'missed_cyc': 0, 'stim_id': 115, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 4 2 0 0]
# Info: {'spikes': array([ 5.1321104 ,  6.90586854,  7.57081753, 12.87820366, 14.69256953,
#        17.31220247]), 'elecs': array([0, 1, 3, 1, 0, 2]), 'action': array([1, 4, 2, 0, 0]), 'missed_cyc': 0, 'stim_id': 116, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 1 1 2 1]
# Info: {'spikes': array([ 8.36583453, 12.47923118, 13.36642453, 15.33925971, 16.38363075,
#        18.27541532, 19.9999    , 19.9999    ]), 'elecs': array([0, 1, 0, 1, 1, 2, 0, 1]), 'action': array([0, 1, 1, 2, 1]), 'missed_cyc': 0, 'stim_id': 117, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 0 0 0 2]
# Info: {'spikes': array([ 4.28806621,  7.86807197, 12.3127081 , 19.9999    , 19.9999    ]), 'elecs': array([0, 1, 2, 1, 2]), 'action': array([1, 0, 0, 0, 2]), 'missed_cyc': 0, 'stim_id': 118, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 0 1 1 1]
# Info: {'spikes': array([ 1.75409929,  8.78134336, 10.71551891, 12.05869892, 13.7448574 ,
#        16.19441393, 18.04401902, 19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([0, 1, 0, 1, 2, 1, 0, 1, 0, 1]), 'action': array([1, 0, 1, 1, 1]), 'missed_cyc': 0, 'stim_id': 119, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 1 0 1 0]
# Info: {'spikes': array([ 4.23047525,  5.79566977, 10.31683688, 11.97703615, 15.41429808,
#        16.25872934, 19.9999    ]), 'elecs': array([3, 0, 0, 1, 1, 0, 1]), 'action': array([4, 1, 0, 1, 0]), 'missed_cyc': 0, 'stim_id': 120, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 4 3 0 0]
# Info: {'spikes': array([ 3.71559478,  6.53496824,  6.87067548, 10.91043435, 12.93214942,
#        14.4487188 ]), 'elecs': array([3, 0, 3, 0, 2, 3]), 'action': array([4, 4, 3, 0, 0]), 'missed_cyc': 0, 'stim_id': 121, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 1 3 3 0]
# Info: {'spikes': array([ 3.81121874,  8.90142152,  9.11742067, 11.19305002, 11.66416121,
#        15.41757401, 15.44285495, 19.9999    ]), 'elecs': array([3, 0, 0, 1, 2, 3, 2, 3]), 'action': array([4, 1, 3, 3, 0]), 'missed_cyc': 0, 'stim_id': 122, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2 4 0 1]
# Info: {'spikes': array([ 2.31820512,  7.52140383,  9.22457648, 11.48061794, 13.01554648,
#        17.34726506, 17.36740255, 19.9999    ]), 'elecs': array([0, 1, 1, 3, 2, 0, 0, 1]), 'action': array([1, 2, 4, 0, 1]), 'missed_cyc': 0, 'stim_id': 123, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 3 1 4 1]
# Info: {'spikes': array([ 8.97181415, 12.51635144, 13.40488278, 15.27704705, 15.89910836,
#        19.24287266, 19.99123265, 19.9999    ]), 'elecs': array([2, 3, 0, 3, 1, 0, 0, 1]), 'action': array([0, 3, 1, 4, 1]), 'missed_cyc': 0, 'stim_id': 124, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 1 0 4 0]
# Info: {'spikes': array([ 3.01492281,  7.20710545,  9.27718005, 12.31476231, 16.01374395,
#        19.78217048]), 'elecs': array([0, 1, 0, 1, 3, 0]), 'action': array([1, 1, 0, 4, 0]), 'missed_cyc': 0, 'stim_id': 125, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 1 3 0 4]
# Info: {'spikes': array([ 6.0999386 , 12.07860087, 13.62590829, 16.71742697, 17.6495131 ,
#        19.9999    , 19.9999    ]), 'elecs': array([0, 1, 2, 2, 3, 3, 0]), 'action': array([0, 1, 3, 0, 4]), 'missed_cyc': 0, 'stim_id': 126, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 4 2 2 1]
# Info: {'spikes': array([ 5.5880478 ,  6.17598238,  7.7094476 , 10.76094734, 12.73450495,
#        14.96586801, 15.52993832, 15.88917242, 17.52223172, 18.77894455,
#        19.9999    , 19.9999    ]), 'elecs': array([2, 3, 3, 1, 0, 3, 2, 1, 1, 0, 2, 1]), 'action': array([3, 4, 2, 2, 1]), 'missed_cyc': 0, 'stim_id': 127, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 1 2 2 2]
# Info: {'spikes': array([ 4.29036922,  7.02206619,  7.08883044,  9.22561492, 12.9080956 ,
#        13.23265037, 15.20633786, 16.56889686, 17.88267268, 19.9999    ,
#        19.9999    , 19.9999    ]), 'elecs': array([1, 2, 0, 1, 1, 1, 2, 1, 3, 2, 1, 2]), 'action': array([2, 1, 2, 2, 2]), 'missed_cyc': 0, 'stim_id': 128, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3 3 2 4]
# Info: {'spikes': array([ 5.75494791,  7.03145877,  8.1623007 , 12.43286442, 13.2037851 ,
#        15.95126842, 16.13758926, 19.9999    , 19.9999    , 19.9999    ]), 'elecs': array([0, 2, 1, 2, 3, 3, 1, 2, 3, 0]), 'action': array([1, 3, 3, 2, 4]), 'missed_cyc': 0, 'stim_id': 129, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [4 1 0 2 2]
# Info: {'spikes': array([ 5.3638071 ,  8.74105164,  8.7885911 , 12.24053807, 15.22219074,
#        15.85191299, 18.38541436, 18.98388967, 19.9999    ]), 'elecs': array([3, 0, 0, 1, 1, 0, 2, 1, 2]), 'action': array([4, 1, 0, 2, 2]), 'missed_cyc': 0, 'stim_id': 130, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [0 2 1 0 3]
# Info: {'spikes': array([ 7.77720307, 12.47028003, 12.64404335, 16.72227884, 19.8976961 ,
#        19.9999    ]), 'elecs': array([1, 2, 0, 1, 2, 3]), 'action': array([0, 2, 1, 0, 3]), 'missed_cyc': 0, 'stim_id': 131, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [3 3 4 1 0]
# Info: {'spikes': array([ 2.62181192,  7.91314014,  8.50427188, 12.05608437, 12.17890463,
#        15.9380913 , 16.37141407, 18.27918008]), 'elecs': array([2, 2, 3, 3, 3, 0, 0, 1]), 'action': array([3, 3, 4, 1, 0]), 'missed_cyc': 0, 'stim_id': 132, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [2 0 4 1 3]
# Info: {'spikes': array([ 2.97614968,  6.97331319,  7.12899959, 12.15457411, 14.58723562,
#        16.90293348, 19.28039246, 19.9999    , 19.9999    ]), 'elecs': array([1, 2, 2, 3, 0, 0, 2, 1, 3]), 'action': array([2, 0, 4, 1, 3]), 'missed_cyc': 0, 'stim_id': 133, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 2 1 4 0]
# Info: {'spikes': array([ 4.99626887,  7.41563843,  7.78359309, 10.0923221 , 10.98380139,
#        11.83612151, 14.47831464, 15.56825693, 19.9999    ]), 'elecs': array([0, 1, 1, 2, 1, 0, 3, 1, 0]), 'action': array([1, 2, 1, 4, 0]), 'missed_cyc': 0, 'stim_id': 134, 'simulated': True, 'comment': 'none'}
# -----------------------------
# Stimulate with action: [1 3 2 4 2]
# Info: {'spikes': array([ 3.61345941,  4.55932898,  8.05219528,  8.06206111, 11.42948203,
#        11.97723889, 15.91982869, 16.5234871 , 19.65201309, 19.9999    ,
#        19.9999    ]), 'elecs': array([3, 0, 2, 1, 3, 1, 3, 2, 0, 1, 2]), 'action': array([1, 3, 2, 4, 2]), 'missed_cyc': 0, 'stim_id': 135, 'simulated': True, 'comment': 'none'}
# -----------------------------

# %%
print(f"Average reward: {total_reward/action_count}")
# Out:
# Average reward: 1.27
